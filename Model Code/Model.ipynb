# %%
import yfinance as yf
import pandas as pd
import datetime
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Define the ticker symbols of DJI's constituent stocks
dji_stocks = [
    'MMM', 'AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CVX', 'CSCO',
    'KO', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'JPM',
    'MCD', 'MRK', 'MSFT', 'NKE', 'PG', 'CRM', 'TRV', 'UNH',
    'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW'
]

start_date = '2023-01-01'  # Adjust the start date to a more recent date due to hourly data limitations
end_date = datetime.datetime.now().strftime('%Y-%m-%d')

# Initialize an empty DataFrame to store historical data for all stocks
all_data = pd.DataFrame()

for symbol in dji_stocks:
    # Download the hourly historical data
    data = yf.download(symbol, start=start_date, end=end_date, interval='1h')

    # Add a 'Ticker' column to the data with the current symbol
    data['Ticker'] = symbol

    # Append the data to the all_data DataFrame
    all_data = all_data.append(data)

# Reset the index, creating a separate index column
all_data = all_data.reset_index(drop=False)

# Rename the new index column
all_data = all_data.rename(columns={'index': 'Timestamp'})

# Save the data to a CSV file
all_data.to_csv('dji_stocks_hourly_historical_data.csv')

print("Hourly historical data for DJI stocks downloaded and saved as dji_stocks_hourly_historical_data.csv")


# Function to convert string to datetime
def str_to_datetime(s):
    return pd.to_datetime(s)

# Function to convert datetime to string
def datetime_to_str(d):
    return d.strftime('%Y-%m-%d')

# Function to create a dataset with a look_back window
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# Function to convert a windowed DataFrame to separate date, X, and y arrays
def windowed_df_to_date_X_y(windowed_dataframe):
    df_as_np = windowed_dataframe.to_numpy()

    dates = df_as_np[:, 0]
    X = df_as_np[:, 1:-1]
    y = df_as_np[:, -1]

    return dates, X, y
    
# Function to train and evaluate a stock LSTM model
def train_and_evaluate_stock(stock_data, symbol):
    np.random.seed(42)
    tf.random.set_seed(42)

    stock_data = stock_data[['Datetime', 'Close']].copy()
    stock_data['Datetime'] = stock_data['Datetime'].apply(str_to_datetime)

    scaler = MinMaxScaler(feature_range=(0, 1))
    stock_data['Close'] = scaler.fit_transform(stock_data['Close'].values.reshape(-1, 1))

    look_back = 10

    stock_data = stock_data[['Close']].copy()
    stock_data = pd.concat([stock_data.shift(look_back - i) for i in range(look_back + 1)], axis=1)
    stock_data = stock_data.dropna()

    train_dates, train_X, train_y = windowed_df_to_date_X_y(stock_data)
    train_X = np.reshape(train_X, (train_X.shape[0], 1, train_X.shape[1]))

    model = Sequential()
    model.add(LSTM(4, input_shape=(1, look_back - 1)))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.fit(train_X, train_y, epochs=100, batch_size=1, verbose=2)

    # Save the trained model
    model.save(f"{symbol}_lstm_model.h5")

    trainPredict = model.predict(train_X)
    trainPredict = scaler.inverse_transform(trainPredict)
    train_y = scaler.inverse_transform(train_y.reshape(-1, 1))

    trainScore = np.sqrt(mean_squared_error(train_y, trainPredict[:, 0]))
    print(f"{symbol} Train Score: {trainScore:.2f} RMSE")

    return model

trained_models = {}

for symbol in dji_stocks:
    stock_data = all_data[all_data['Ticker'] == symbol]
    print(f"Training model for {symbol}...")
    model = train_and_evaluate_stock(stock_data, symbol)
    trained_models[symbol] = model
    print(f"Finished training model for {symbol}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-1-59e02f178a36>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(data)
# Streaming output truncated to the last 5000 lines.
# 494/494 - 1s - loss: 0.0011 - 839ms/epoch - 2ms/step
# Epoch 51/100
# 494/494 - 1s - loss: 0.0011 - 783ms/epoch - 2ms/step
# Epoch 52/100
# 494/494 - 1s - loss: 0.0011 - 807ms/epoch - 2ms/step
# Epoch 53/100
# 494/494 - 1s - loss: 0.0012 - 810ms/epoch - 2ms/step
# Epoch 54/100
# 494/494 - 1s - loss: 0.0011 - 812ms/epoch - 2ms/step
# Epoch 55/100
# 494/494 - 1s - loss: 0.0011 - 808ms/epoch - 2ms/step
# Epoch 56/100
# 494/494 - 1s - loss: 0.0012 - 799ms/epoch - 2ms/step
# Epoch 57/100
# 494/494 - 1s - loss: 0.0011 - 820ms/epoch - 2ms/step
# Epoch 58/100
# 494/494 - 1s - loss: 0.0011 - 819ms/epoch - 2ms/step
# Epoch 59/100
# 494/494 - 1s - loss: 0.0011 - 804ms/epoch - 2ms/step
# Epoch 60/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 61/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 62/100
# 494/494 - 1s - loss: 0.0011 - 935ms/epoch - 2ms/step
# Epoch 63/100
# 494/494 - 1s - loss: 0.0011 - 789ms/epoch - 2ms/step
# Epoch 64/100
# 494/494 - 1s - loss: 0.0011 - 783ms/epoch - 2ms/step
# Epoch 65/100
# 494/494 - 1s - loss: 0.0011 - 796ms/epoch - 2ms/step
# Epoch 66/100
# 494/494 - 1s - loss: 0.0011 - 802ms/epoch - 2ms/step
# Epoch 67/100
# 494/494 - 1s - loss: 0.0012 - 793ms/epoch - 2ms/step
# Epoch 68/100
# 494/494 - 1s - loss: 0.0011 - 805ms/epoch - 2ms/step
# Epoch 69/100
# 494/494 - 1s - loss: 0.0011 - 789ms/epoch - 2ms/step
# Epoch 70/100
# 494/494 - 1s - loss: 0.0011 - 801ms/epoch - 2ms/step
# Epoch 71/100
# 494/494 - 1s - loss: 0.0011 - 796ms/epoch - 2ms/step
# Epoch 72/100
# 494/494 - 1s - loss: 0.0011 - 791ms/epoch - 2ms/step
# Epoch 73/100
# 494/494 - 1s - loss: 0.0011 - 789ms/epoch - 2ms/step
# Epoch 74/100
# 494/494 - 1s - loss: 0.0011 - 893ms/epoch - 2ms/step
# Epoch 75/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 76/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 77/100
# 494/494 - 1s - loss: 0.0011 - 834ms/epoch - 2ms/step
# Epoch 78/100
# 494/494 - 1s - loss: 0.0011 - 787ms/epoch - 2ms/step
# Epoch 79/100
# 494/494 - 1s - loss: 0.0011 - 800ms/epoch - 2ms/step
# Epoch 80/100
# 494/494 - 1s - loss: 0.0010 - 790ms/epoch - 2ms/step
# Epoch 81/100
# 494/494 - 1s - loss: 0.0011 - 783ms/epoch - 2ms/step
# Epoch 82/100
# 494/494 - 1s - loss: 0.0011 - 797ms/epoch - 2ms/step
# Epoch 83/100
# 494/494 - 1s - loss: 0.0011 - 791ms/epoch - 2ms/step
# Epoch 84/100
# 494/494 - 1s - loss: 0.0011 - 781ms/epoch - 2ms/step
# Epoch 85/100
# 494/494 - 1s - loss: 0.0011 - 776ms/epoch - 2ms/step
# Epoch 86/100
# 494/494 - 1s - loss: 0.0010 - 814ms/epoch - 2ms/step
# Epoch 87/100
# 494/494 - 1s - loss: 0.0011 - 792ms/epoch - 2ms/step
# Epoch 88/100
# 494/494 - 1s - loss: 0.0011 - 775ms/epoch - 2ms/step
# Epoch 89/100
# 494/494 - 1s - loss: 0.0011 - 887ms/epoch - 2ms/step
# Epoch 90/100
# 494/494 - 1s - loss: 0.0010 - 1s/epoch - 2ms/step
# Epoch 91/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 92/100
# 494/494 - 1s - loss: 0.0010 - 800ms/epoch - 2ms/step
# Epoch 93/100
# 494/494 - 1s - loss: 0.0011 - 793ms/epoch - 2ms/step
# Epoch 94/100
# 494/494 - 1s - loss: 0.0011 - 790ms/epoch - 2ms/step
# Epoch 95/100
# 494/494 - 1s - loss: 0.0011 - 789ms/epoch - 2ms/step
# Epoch 96/100
# 494/494 - 1s - loss: 0.0011 - 788ms/epoch - 2ms/step
# Epoch 97/100
# 494/494 - 1s - loss: 0.0011 - 784ms/epoch - 2ms/step
# Epoch 98/100
# 494/494 - 1s - loss: 0.0011 - 801ms/epoch - 2ms/step
# Epoch 99/100
# 494/494 - 1s - loss: 0.0010 - 815ms/epoch - 2ms/step
# Epoch 100/100
# 494/494 - 1s - loss: 0.0010 - 788ms/epoch - 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# CAT Train Score: 2.00 RMSE
# Finished training model for CAT
# Training model for CVX...
# Epoch 1/100
# 494/494 - 3s - loss: 0.0156 - 3s/epoch - 6ms/step
# Epoch 2/100
# 494/494 - 1s - loss: 0.0026 - 1s/epoch - 2ms/step
# Epoch 3/100
# 494/494 - 1s - loss: 0.0024 - 892ms/epoch - 2ms/step
# Epoch 4/100
# 494/494 - 1s - loss: 0.0022 - 795ms/epoch - 2ms/step
# Epoch 5/100
# 494/494 - 1s - loss: 0.0020 - 820ms/epoch - 2ms/step
# Epoch 6/100
# 494/494 - 1s - loss: 0.0018 - 806ms/epoch - 2ms/step
# Epoch 7/100
# 494/494 - 1s - loss: 0.0016 - 802ms/epoch - 2ms/step
# Epoch 8/100
# 494/494 - 1s - loss: 0.0015 - 816ms/epoch - 2ms/step
# Epoch 9/100
# 494/494 - 1s - loss: 0.0014 - 792ms/epoch - 2ms/step
# Epoch 10/100
# 494/494 - 1s - loss: 0.0013 - 797ms/epoch - 2ms/step
# Epoch 11/100
# 494/494 - 1s - loss: 0.0012 - 816ms/epoch - 2ms/step
# Epoch 12/100
# 494/494 - 1s - loss: 0.0011 - 801ms/epoch - 2ms/step
# Epoch 13/100
# 494/494 - 1s - loss: 0.0012 - 779ms/epoch - 2ms/step
# Epoch 14/100
# 494/494 - 1s - loss: 0.0011 - 810ms/epoch - 2ms/step
# Epoch 15/100
# 494/494 - 1s - loss: 0.0010 - 915ms/epoch - 2ms/step
# Epoch 16/100
# 494/494 - 1s - loss: 0.0010 - 1s/epoch - 2ms/step
# Epoch 17/100
# 494/494 - 1s - loss: 0.0010 - 1s/epoch - 2ms/step
# Epoch 18/100
# 494/494 - 1s - loss: 0.0010 - 784ms/epoch - 2ms/step
# Epoch 19/100
# 494/494 - 1s - loss: 0.0011 - 806ms/epoch - 2ms/step
# Epoch 20/100
# 494/494 - 1s - loss: 9.8559e-04 - 821ms/epoch - 2ms/step
# Epoch 21/100
# 494/494 - 1s - loss: 0.0011 - 799ms/epoch - 2ms/step
# Epoch 22/100
# 494/494 - 1s - loss: 0.0010 - 794ms/epoch - 2ms/step
# Epoch 23/100
# 494/494 - 1s - loss: 9.9849e-04 - 828ms/epoch - 2ms/step
# Epoch 24/100
# 494/494 - 1s - loss: 0.0010 - 805ms/epoch - 2ms/step
# Epoch 25/100
# 494/494 - 1s - loss: 0.0010 - 808ms/epoch - 2ms/step
# Epoch 26/100
# 494/494 - 1s - loss: 9.8618e-04 - 782ms/epoch - 2ms/step
# Epoch 27/100
# 494/494 - 1s - loss: 0.0010 - 788ms/epoch - 2ms/step
# Epoch 28/100
# 494/494 - 1s - loss: 9.8856e-04 - 803ms/epoch - 2ms/step
# Epoch 29/100
# 494/494 - 1s - loss: 0.0010 - 797ms/epoch - 2ms/step
# Epoch 30/100
# 494/494 - 1s - loss: 9.6262e-04 - 997ms/epoch - 2ms/step
# Epoch 31/100
# 494/494 - 1s - loss: 9.7275e-04 - 1s/epoch - 2ms/step
# Epoch 32/100
# 494/494 - 1s - loss: 9.9602e-04 - 1s/epoch - 2ms/step
# Epoch 33/100
# 494/494 - 1s - loss: 0.0010 - 816ms/epoch - 2ms/step
# Epoch 34/100
# 494/494 - 1s - loss: 0.0010 - 810ms/epoch - 2ms/step
# Epoch 35/100
# 494/494 - 1s - loss: 0.0010 - 799ms/epoch - 2ms/step
# Epoch 36/100
# 494/494 - 1s - loss: 0.0010 - 804ms/epoch - 2ms/step
# Epoch 37/100
# 494/494 - 1s - loss: 9.8002e-04 - 803ms/epoch - 2ms/step
# Epoch 38/100
# 494/494 - 1s - loss: 0.0010 - 780ms/epoch - 2ms/step
# Epoch 39/100
# 494/494 - 1s - loss: 9.3951e-04 - 790ms/epoch - 2ms/step
# Epoch 40/100
# 494/494 - 1s - loss: 9.6435e-04 - 788ms/epoch - 2ms/step
# Epoch 41/100
# 494/494 - 1s - loss: 9.9301e-04 - 793ms/epoch - 2ms/step
# Epoch 42/100
# 494/494 - 1s - loss: 0.0010 - 805ms/epoch - 2ms/step
# Epoch 43/100
# 494/494 - 1s - loss: 0.0010 - 794ms/epoch - 2ms/step
# Epoch 44/100
# 494/494 - 1s - loss: 9.6810e-04 - 770ms/epoch - 2ms/step
# Epoch 45/100
# 494/494 - 1s - loss: 9.4608e-04 - 1s/epoch - 2ms/step
# Epoch 46/100
# 494/494 - 1s - loss: 9.4237e-04 - 1s/epoch - 2ms/step
# Epoch 47/100
# 494/494 - 1s - loss: 0.0010 - 965ms/epoch - 2ms/step
# Epoch 48/100
# 494/494 - 1s - loss: 0.0010 - 784ms/epoch - 2ms/step
# Epoch 49/100
# 494/494 - 1s - loss: 9.9325e-04 - 800ms/epoch - 2ms/step
# Epoch 50/100
# 494/494 - 1s - loss: 9.0756e-04 - 781ms/epoch - 2ms/step
# Epoch 51/100
# 494/494 - 1s - loss: 9.4999e-04 - 813ms/epoch - 2ms/step
# Epoch 52/100
# 494/494 - 1s - loss: 9.3399e-04 - 797ms/epoch - 2ms/step
# Epoch 53/100
# 494/494 - 1s - loss: 9.9027e-04 - 798ms/epoch - 2ms/step
# Epoch 54/100
# 494/494 - 1s - loss: 9.5384e-04 - 817ms/epoch - 2ms/step
# Epoch 55/100
# 494/494 - 1s - loss: 0.0010 - 797ms/epoch - 2ms/step
# Epoch 56/100
# 494/494 - 1s - loss: 9.5512e-04 - 928ms/epoch - 2ms/step
# Epoch 57/100
# 494/494 - 1s - loss: 9.5915e-04 - 1s/epoch - 2ms/step
# Epoch 58/100
# 494/494 - 1s - loss: 9.5620e-04 - 1s/epoch - 2ms/step
# Epoch 59/100
# 494/494 - 1s - loss: 9.7389e-04 - 1s/epoch - 2ms/step
# Epoch 60/100
# 494/494 - 1s - loss: 9.6714e-04 - 1s/epoch - 2ms/step
# Epoch 61/100
# 494/494 - 1s - loss: 9.5300e-04 - 855ms/epoch - 2ms/step
# Epoch 62/100
# 494/494 - 1s - loss: 9.0198e-04 - 790ms/epoch - 2ms/step
# Epoch 63/100
# 494/494 - 1s - loss: 9.3091e-04 - 803ms/epoch - 2ms/step
# Epoch 64/100
# 494/494 - 1s - loss: 9.3705e-04 - 824ms/epoch - 2ms/step
# Epoch 65/100
# 494/494 - 1s - loss: 9.2966e-04 - 813ms/epoch - 2ms/step
# Epoch 66/100
# 494/494 - 1s - loss: 9.6425e-04 - 793ms/epoch - 2ms/step
# Epoch 67/100
# 494/494 - 1s - loss: 0.0010 - 787ms/epoch - 2ms/step
# Epoch 68/100
# 494/494 - 1s - loss: 9.6774e-04 - 789ms/epoch - 2ms/step
# Epoch 69/100
# 494/494 - 1s - loss: 9.5628e-04 - 800ms/epoch - 2ms/step
# Epoch 70/100
# 494/494 - 1s - loss: 9.2578e-04 - 810ms/epoch - 2ms/step
# Epoch 71/100
# 494/494 - 1s - loss: 9.5627e-04 - 785ms/epoch - 2ms/step
# Epoch 72/100
# 494/494 - 1s - loss: 9.2080e-04 - 789ms/epoch - 2ms/step
# Epoch 73/100
# 494/494 - 1s - loss: 9.5166e-04 - 900ms/epoch - 2ms/step
# Epoch 74/100
# 494/494 - 1s - loss: 8.8220e-04 - 1s/epoch - 2ms/step
# Epoch 75/100
# 494/494 - 1s - loss: 9.5951e-04 - 1s/epoch - 2ms/step
# Epoch 76/100
# 494/494 - 1s - loss: 9.1502e-04 - 827ms/epoch - 2ms/step
# Epoch 77/100
# 494/494 - 1s - loss: 9.3440e-04 - 790ms/epoch - 2ms/step
# Epoch 78/100
# 494/494 - 1s - loss: 9.0040e-04 - 793ms/epoch - 2ms/step
# Epoch 79/100
# 494/494 - 1s - loss: 9.9041e-04 - 785ms/epoch - 2ms/step
# Epoch 80/100
# 494/494 - 1s - loss: 9.0678e-04 - 818ms/epoch - 2ms/step
# Epoch 81/100
# 494/494 - 1s - loss: 9.1527e-04 - 777ms/epoch - 2ms/step
# Epoch 82/100
# 494/494 - 1s - loss: 9.1185e-04 - 792ms/epoch - 2ms/step
# Epoch 83/100
# 494/494 - 1s - loss: 9.4401e-04 - 804ms/epoch - 2ms/step
# Epoch 84/100
# 494/494 - 1s - loss: 9.9316e-04 - 802ms/epoch - 2ms/step
# Epoch 85/100
# 494/494 - 1s - loss: 9.1227e-04 - 781ms/epoch - 2ms/step
# Epoch 86/100
# 494/494 - 1s - loss: 9.4649e-04 - 799ms/epoch - 2ms/step
# Epoch 87/100
# 494/494 - 1s - loss: 9.3746e-04 - 828ms/epoch - 2ms/step
# Epoch 88/100
# 494/494 - 1s - loss: 9.2195e-04 - 988ms/epoch - 2ms/step
# Epoch 89/100
# 494/494 - 1s - loss: 9.1341e-04 - 1s/epoch - 2ms/step
# Epoch 90/100
# 494/494 - 1s - loss: 9.4470e-04 - 1s/epoch - 2ms/step
# Epoch 91/100
# 494/494 - 1s - loss: 9.5383e-04 - 798ms/epoch - 2ms/step
# Epoch 92/100
# 494/494 - 1s - loss: 9.0079e-04 - 796ms/epoch - 2ms/step
# Epoch 93/100
# 494/494 - 1s - loss: 9.1718e-04 - 801ms/epoch - 2ms/step
# Epoch 94/100
# 494/494 - 1s - loss: 9.2707e-04 - 800ms/epoch - 2ms/step
# Epoch 95/100
# 494/494 - 1s - loss: 9.2928e-04 - 795ms/epoch - 2ms/step
# Epoch 96/100
# 494/494 - 1s - loss: 9.4251e-04 - 787ms/epoch - 2ms/step
# Epoch 97/100
# 494/494 - 1s - loss: 9.5526e-04 - 804ms/epoch - 2ms/step
# Epoch 98/100
# 494/494 - 1s - loss: 9.3806e-04 - 789ms/epoch - 2ms/step
# Epoch 99/100
# 494/494 - 1s - loss: 9.6447e-04 - 800ms/epoch - 2ms/step
# Epoch 100/100
# 494/494 - 1s - loss: 8.8116e-04 - 796ms/epoch - 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# CVX Train Score: 1.07 RMSE
# Finished training model for CVX
# Training model for CSCO...
# Epoch 1/100
# 494/494 - 3s - loss: 0.0974 - 3s/epoch - 7ms/step
# Epoch 2/100
# 494/494 - 1s - loss: 0.0085 - 848ms/epoch - 2ms/step
# Epoch 3/100
# 494/494 - 1s - loss: 0.0046 - 811ms/epoch - 2ms/step
# Epoch 4/100
# 494/494 - 1s - loss: 0.0036 - 799ms/epoch - 2ms/step
# Epoch 5/100
# 494/494 - 1s - loss: 0.0031 - 792ms/epoch - 2ms/step
# Epoch 6/100
# 494/494 - 1s - loss: 0.0028 - 829ms/epoch - 2ms/step
# Epoch 7/100
# 494/494 - 1s - loss: 0.0025 - 796ms/epoch - 2ms/step
# Epoch 8/100
# 494/494 - 1s - loss: 0.0023 - 822ms/epoch - 2ms/step
# Epoch 9/100
# 494/494 - 1s - loss: 0.0023 - 802ms/epoch - 2ms/step
# Epoch 10/100
# 494/494 - 1s - loss: 0.0023 - 799ms/epoch - 2ms/step
# Epoch 11/100
# 494/494 - 1s - loss: 0.0022 - 796ms/epoch - 2ms/step
# Epoch 12/100
# 494/494 - 1s - loss: 0.0021 - 802ms/epoch - 2ms/step
# Epoch 13/100
# 494/494 - 1s - loss: 0.0020 - 801ms/epoch - 2ms/step
# Epoch 14/100
# 494/494 - 1s - loss: 0.0020 - 917ms/epoch - 2ms/step
# Epoch 15/100
# 494/494 - 1s - loss: 0.0020 - 1s/epoch - 2ms/step
# Epoch 16/100
# 494/494 - 1s - loss: 0.0019 - 1s/epoch - 2ms/step
# Epoch 17/100
# 494/494 - 1s - loss: 0.0020 - 796ms/epoch - 2ms/step
# Epoch 18/100
# 494/494 - 1s - loss: 0.0019 - 785ms/epoch - 2ms/step
# Epoch 19/100
# 494/494 - 1s - loss: 0.0020 - 797ms/epoch - 2ms/step
# Epoch 20/100
# 494/494 - 1s - loss: 0.0019 - 819ms/epoch - 2ms/step
# Epoch 21/100
# 494/494 - 1s - loss: 0.0019 - 821ms/epoch - 2ms/step
# Epoch 22/100
# 494/494 - 1s - loss: 0.0019 - 778ms/epoch - 2ms/step
# Epoch 23/100
# 494/494 - 1s - loss: 0.0019 - 812ms/epoch - 2ms/step
# Epoch 24/100
# 494/494 - 1s - loss: 0.0019 - 817ms/epoch - 2ms/step
# Epoch 25/100
# 494/494 - 1s - loss: 0.0019 - 808ms/epoch - 2ms/step
# Epoch 26/100
# 494/494 - 1s - loss: 0.0019 - 803ms/epoch - 2ms/step
# Epoch 27/100
# 494/494 - 1s - loss: 0.0019 - 767ms/epoch - 2ms/step
# Epoch 28/100
# 494/494 - 1s - loss: 0.0018 - 794ms/epoch - 2ms/step
# Epoch 29/100
# 494/494 - 1s - loss: 0.0018 - 1s/epoch - 2ms/step
# Epoch 30/100
# 494/494 - 1s - loss: 0.0018 - 1s/epoch - 2ms/step
# Epoch 31/100
# 494/494 - 1s - loss: 0.0018 - 1s/epoch - 2ms/step
# Epoch 32/100
# 494/494 - 1s - loss: 0.0018 - 1s/epoch - 2ms/step
# Epoch 33/100
# 494/494 - 1s - loss: 0.0019 - 792ms/epoch - 2ms/step
# Epoch 34/100
# 494/494 - 1s - loss: 0.0018 - 786ms/epoch - 2ms/step
# Epoch 35/100
# 494/494 - 1s - loss: 0.0018 - 805ms/epoch - 2ms/step
# Epoch 36/100
# 494/494 - 1s - loss: 0.0018 - 782ms/epoch - 2ms/step
# Epoch 37/100
# 494/494 - 1s - loss: 0.0018 - 801ms/epoch - 2ms/step
# Epoch 38/100
# 494/494 - 1s - loss: 0.0017 - 800ms/epoch - 2ms/step
# Epoch 39/100
# 494/494 - 1s - loss: 0.0018 - 788ms/epoch - 2ms/step
# Epoch 40/100
# 494/494 - 1s - loss: 0.0018 - 773ms/epoch - 2ms/step
# Epoch 41/100
# 494/494 - 1s - loss: 0.0018 - 807ms/epoch - 2ms/step
# Epoch 42/100
# 494/494 - 1s - loss: 0.0018 - 787ms/epoch - 2ms/step
# Epoch 43/100
# 494/494 - 1s - loss: 0.0018 - 910ms/epoch - 2ms/step
# Epoch 44/100
# 494/494 - 1s - loss: 0.0017 - 1s/epoch - 2ms/step
# Epoch 45/100
# 494/494 - 1s - loss: 0.0017 - 1s/epoch - 2ms/step
# Epoch 46/100
# 494/494 - 1s - loss: 0.0018 - 821ms/epoch - 2ms/step
# Epoch 47/100
# 494/494 - 1s - loss: 0.0018 - 796ms/epoch - 2ms/step
# Epoch 48/100
# 494/494 - 1s - loss: 0.0017 - 784ms/epoch - 2ms/step
# Epoch 49/100
# 494/494 - 1s - loss: 0.0018 - 828ms/epoch - 2ms/step
# Epoch 50/100
# 494/494 - 1s - loss: 0.0017 - 806ms/epoch - 2ms/step
# Epoch 51/100
# 494/494 - 1s - loss: 0.0017 - 792ms/epoch - 2ms/step
# Epoch 52/100
# 494/494 - 1s - loss: 0.0017 - 818ms/epoch - 2ms/step
# Epoch 53/100
# 494/494 - 1s - loss: 0.0017 - 771ms/epoch - 2ms/step
# Epoch 54/100
# 494/494 - 1s - loss: 0.0017 - 778ms/epoch - 2ms/step
# Epoch 55/100
# 494/494 - 1s - loss: 0.0017 - 802ms/epoch - 2ms/step
# Epoch 56/100
# 494/494 - 1s - loss: 0.0017 - 837ms/epoch - 2ms/step
# Epoch 57/100
# 494/494 - 1s - loss: 0.0017 - 807ms/epoch - 2ms/step
# Epoch 58/100
# 494/494 - 1s - loss: 0.0017 - 1s/epoch - 2ms/step
# Epoch 59/100
# 494/494 - 1s - loss: 0.0017 - 1s/epoch - 2ms/step
# Epoch 60/100
# 494/494 - 1s - loss: 0.0018 - 1s/epoch - 2ms/step
# Epoch 61/100
# 494/494 - 1s - loss: 0.0017 - 814ms/epoch - 2ms/step
# Epoch 62/100
# 494/494 - 1s - loss: 0.0017 - 794ms/epoch - 2ms/step
# Epoch 63/100
# 494/494 - 1s - loss: 0.0017 - 809ms/epoch - 2ms/step
# Epoch 64/100
# 494/494 - 1s - loss: 0.0017 - 794ms/epoch - 2ms/step
# Epoch 65/100
# 494/494 - 1s - loss: 0.0017 - 799ms/epoch - 2ms/step
# Epoch 66/100
# 494/494 - 1s - loss: 0.0018 - 775ms/epoch - 2ms/step
# Epoch 67/100
# 494/494 - 1s - loss: 0.0017 - 817ms/epoch - 2ms/step
# Epoch 68/100
# 494/494 - 1s - loss: 0.0017 - 799ms/epoch - 2ms/step
# Epoch 69/100
# 494/494 - 1s - loss: 0.0017 - 812ms/epoch - 2ms/step
# Epoch 70/100
# 494/494 - 1s - loss: 0.0017 - 796ms/epoch - 2ms/step
# Epoch 71/100
# 494/494 - 1s - loss: 0.0017 - 797ms/epoch - 2ms/step
# Epoch 72/100
# 494/494 - 1s - loss: 0.0017 - 810ms/epoch - 2ms/step
# Epoch 73/100
# 494/494 - 1s - loss: 0.0016 - 1s/epoch - 2ms/step
# Epoch 74/100
# 494/494 - 1s - loss: 0.0017 - 1s/epoch - 2ms/step
# Epoch 75/100
# 494/494 - 1s - loss: 0.0017 - 914ms/epoch - 2ms/step
# Epoch 76/100
# 494/494 - 1s - loss: 0.0017 - 796ms/epoch - 2ms/step
# Epoch 77/100
# 494/494 - 1s - loss: 0.0017 - 801ms/epoch - 2ms/step
# Epoch 78/100
# 494/494 - 1s - loss: 0.0017 - 809ms/epoch - 2ms/step
# Epoch 79/100
# 494/494 - 1s - loss: 0.0016 - 818ms/epoch - 2ms/step
# Epoch 80/100
# 494/494 - 1s - loss: 0.0017 - 791ms/epoch - 2ms/step
# Epoch 81/100
# 494/494 - 1s - loss: 0.0017 - 789ms/epoch - 2ms/step
# Epoch 82/100
# 494/494 - 1s - loss: 0.0016 - 796ms/epoch - 2ms/step
# Epoch 83/100
# 494/494 - 1s - loss: 0.0017 - 794ms/epoch - 2ms/step
# Epoch 84/100
# 494/494 - 1s - loss: 0.0017 - 802ms/epoch - 2ms/step
# Epoch 85/100
# 494/494 - 1s - loss: 0.0016 - 807ms/epoch - 2ms/step
# Epoch 86/100
# 494/494 - 1s - loss: 0.0017 - 798ms/epoch - 2ms/step
# Epoch 87/100
# 494/494 - 1s - loss: 0.0016 - 885ms/epoch - 2ms/step
# Epoch 88/100
# 494/494 - 1s - loss: 0.0016 - 1s/epoch - 2ms/step
# Epoch 89/100
# 494/494 - 1s - loss: 0.0016 - 1s/epoch - 2ms/step
# Epoch 90/100
# 494/494 - 1s - loss: 0.0017 - 813ms/epoch - 2ms/step
# Epoch 91/100
# 494/494 - 1s - loss: 0.0017 - 827ms/epoch - 2ms/step
# Epoch 92/100
# 494/494 - 1s - loss: 0.0017 - 789ms/epoch - 2ms/step
# Epoch 93/100
# 494/494 - 1s - loss: 0.0016 - 805ms/epoch - 2ms/step
# Epoch 94/100
# 494/494 - 1s - loss: 0.0016 - 798ms/epoch - 2ms/step
# Epoch 95/100
# 494/494 - 1s - loss: 0.0017 - 798ms/epoch - 2ms/step
# Epoch 96/100
# 494/494 - 1s - loss: 0.0017 - 808ms/epoch - 2ms/step
# Epoch 97/100
# 494/494 - 1s - loss: 0.0017 - 786ms/epoch - 2ms/step
# Epoch 98/100
# 494/494 - 1s - loss: 0.0016 - 812ms/epoch - 2ms/step
# Epoch 99/100
# 494/494 - 1s - loss: 0.0016 - 800ms/epoch - 2ms/step
# Epoch 100/100
# 494/494 - 1s - loss: 0.0016 - 806ms/epoch - 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# CSCO Train Score: 0.24 RMSE
# Finished training model for CSCO
# Training model for KO...
# Epoch 1/100
# 494/494 - 3s - loss: 0.0524 - 3s/epoch - 5ms/step
# Epoch 2/100
# 494/494 - 1s - loss: 0.0064 - 1s/epoch - 2ms/step
# Epoch 3/100
# 494/494 - 1s - loss: 0.0047 - 1s/epoch - 2ms/step
# Epoch 4/100
# 494/494 - 1s - loss: 0.0042 - 910ms/epoch - 2ms/step
# Epoch 5/100
# 494/494 - 1s - loss: 0.0037 - 837ms/epoch - 2ms/step
# Epoch 6/100
# 494/494 - 1s - loss: 0.0031 - 790ms/epoch - 2ms/step
# Epoch 7/100
# 494/494 - 1s - loss: 0.0028 - 791ms/epoch - 2ms/step
# Epoch 8/100
# 494/494 - 1s - loss: 0.0026 - 788ms/epoch - 2ms/step
# Epoch 9/100
# 494/494 - 1s - loss: 0.0024 - 807ms/epoch - 2ms/step
# Epoch 10/100
# 494/494 - 1s - loss: 0.0024 - 799ms/epoch - 2ms/step
# Epoch 11/100
# 494/494 - 1s - loss: 0.0023 - 785ms/epoch - 2ms/step
# Epoch 12/100
# 494/494 - 1s - loss: 0.0022 - 785ms/epoch - 2ms/step
# Epoch 13/100
# 494/494 - 1s - loss: 0.0022 - 808ms/epoch - 2ms/step
# Epoch 14/100
# 494/494 - 1s - loss: 0.0023 - 784ms/epoch - 2ms/step
# Epoch 15/100
# 494/494 - 1s - loss: 0.0023 - 789ms/epoch - 2ms/step
# Epoch 16/100
# 494/494 - 1s - loss: 0.0021 - 871ms/epoch - 2ms/step
# Epoch 17/100
# 494/494 - 1s - loss: 0.0021 - 1s/epoch - 2ms/step
# Epoch 18/100
# 494/494 - 1s - loss: 0.0020 - 1s/epoch - 2ms/step
# Epoch 19/100
# 494/494 - 1s - loss: 0.0021 - 855ms/epoch - 2ms/step
# Epoch 20/100
# 494/494 - 1s - loss: 0.0021 - 807ms/epoch - 2ms/step
# Epoch 21/100
# 494/494 - 1s - loss: 0.0020 - 808ms/epoch - 2ms/step
# Epoch 22/100
# 494/494 - 1s - loss: 0.0021 - 799ms/epoch - 2ms/step
# Epoch 23/100
# 494/494 - 1s - loss: 0.0021 - 791ms/epoch - 2ms/step
# Epoch 24/100
# 494/494 - 1s - loss: 0.0021 - 794ms/epoch - 2ms/step
# Epoch 25/100
# 494/494 - 1s - loss: 0.0021 - 812ms/epoch - 2ms/step
# Epoch 26/100
# 494/494 - 1s - loss: 0.0021 - 791ms/epoch - 2ms/step
# Epoch 27/100
# 494/494 - 1s - loss: 0.0021 - 812ms/epoch - 2ms/step
# Epoch 28/100
# 494/494 - 1s - loss: 0.0020 - 793ms/epoch - 2ms/step
# Epoch 29/100
# 494/494 - 1s - loss: 0.0020 - 796ms/epoch - 2ms/step
# Epoch 30/100
# 494/494 - 1s - loss: 0.0020 - 818ms/epoch - 2ms/step
# Epoch 31/100
# 494/494 - 1s - loss: 0.0020 - 932ms/epoch - 2ms/step
# Epoch 32/100
# 494/494 - 1s - loss: 0.0021 - 1s/epoch - 2ms/step
# Epoch 33/100
# 494/494 - 1s - loss: 0.0021 - 1s/epoch - 2ms/step
# Epoch 34/100
# 494/494 - 1s - loss: 0.0020 - 809ms/epoch - 2ms/step
# Epoch 35/100
# 494/494 - 1s - loss: 0.0021 - 803ms/epoch - 2ms/step
# Epoch 36/100
# 494/494 - 1s - loss: 0.0020 - 797ms/epoch - 2ms/step
# Epoch 37/100
# 494/494 - 1s - loss: 0.0020 - 810ms/epoch - 2ms/step
# Epoch 38/100
# 494/494 - 1s - loss: 0.0020 - 817ms/epoch - 2ms/step
# Epoch 39/100
# 494/494 - 1s - loss: 0.0020 - 798ms/epoch - 2ms/step
# Epoch 40/100
# 494/494 - 1s - loss: 0.0019 - 792ms/epoch - 2ms/step
# Epoch 41/100
# 494/494 - 1s - loss: 0.0020 - 794ms/epoch - 2ms/step
# Epoch 42/100
# 494/494 - 1s - loss: 0.0020 - 789ms/epoch - 2ms/step
# Epoch 43/100
# 494/494 - 1s - loss: 0.0020 - 794ms/epoch - 2ms/step
# Epoch 44/100
# 494/494 - 1s - loss: 0.0020 - 795ms/epoch - 2ms/step
# Epoch 45/100
# 494/494 - 1s - loss: 0.0020 - 811ms/epoch - 2ms/step
# Epoch 46/100
# 494/494 - 1s - loss: 0.0020 - 1s/epoch - 2ms/step
# Epoch 47/100
# 494/494 - 1s - loss: 0.0020 - 1s/epoch - 2ms/step
# Epoch 48/100
# 494/494 - 1s - loss: 0.0020 - 1s/epoch - 2ms/step
# Epoch 49/100
# 494/494 - 1s - loss: 0.0020 - 812ms/epoch - 2ms/step
# Epoch 50/100
# 494/494 - 1s - loss: 0.0019 - 776ms/epoch - 2ms/step
# Epoch 51/100
# 494/494 - 1s - loss: 0.0020 - 792ms/epoch - 2ms/step
# Epoch 52/100
# 494/494 - 1s - loss: 0.0020 - 790ms/epoch - 2ms/step
# Epoch 53/100
# 494/494 - 1s - loss: 0.0020 - 820ms/epoch - 2ms/step
# Epoch 54/100
# 494/494 - 1s - loss: 0.0020 - 783ms/epoch - 2ms/step
# Epoch 55/100
# 494/494 - 1s - loss: 0.0019 - 785ms/epoch - 2ms/step
# Epoch 56/100
# 494/494 - 1s - loss: 0.0020 - 791ms/epoch - 2ms/step
# Epoch 57/100
# 494/494 - 1s - loss: 0.0019 - 794ms/epoch - 2ms/step
# Epoch 58/100
# 494/494 - 1s - loss: 0.0019 - 789ms/epoch - 2ms/step
# Epoch 59/100
# 494/494 - 1s - loss: 0.0019 - 782ms/epoch - 2ms/step
# Epoch 60/100
# 494/494 - 1s - loss: 0.0020 - 776ms/epoch - 2ms/step
# Epoch 61/100
# 494/494 - 1s - loss: 0.0020 - 1s/epoch - 2ms/step
# Epoch 62/100
# 494/494 - 1s - loss: 0.0020 - 1s/epoch - 2ms/step
# Epoch 63/100
# 494/494 - 1s - loss: 0.0019 - 932ms/epoch - 2ms/step
# Epoch 64/100
# 494/494 - 1s - loss: 0.0020 - 792ms/epoch - 2ms/step
# Epoch 65/100
# 494/494 - 1s - loss: 0.0020 - 810ms/epoch - 2ms/step
# Epoch 66/100
# 494/494 - 1s - loss: 0.0020 - 775ms/epoch - 2ms/step
# Epoch 67/100
# 494/494 - 1s - loss: 0.0020 - 778ms/epoch - 2ms/step
# Epoch 68/100
# 494/494 - 1s - loss: 0.0019 - 784ms/epoch - 2ms/step
# Epoch 69/100
# 494/494 - 1s - loss: 0.0019 - 795ms/epoch - 2ms/step
# Epoch 70/100
# 494/494 - 1s - loss: 0.0020 - 812ms/epoch - 2ms/step
# Epoch 71/100
# 494/494 - 1s - loss: 0.0019 - 801ms/epoch - 2ms/step
# Epoch 72/100
# 494/494 - 1s - loss: 0.0020 - 787ms/epoch - 2ms/step
# Epoch 73/100
# 494/494 - 1s - loss: 0.0019 - 784ms/epoch - 2ms/step
# Epoch 74/100
# 494/494 - 1s - loss: 0.0019 - 799ms/epoch - 2ms/step
# Epoch 75/100
# 494/494 - 1s - loss: 0.0019 - 829ms/epoch - 2ms/step
# Epoch 76/100
# 494/494 - 1s - loss: 0.0019 - 1s/epoch - 2ms/step
# Epoch 77/100
# 494/494 - 1s - loss: 0.0019 - 1s/epoch - 2ms/step
# Epoch 78/100
# 494/494 - 1s - loss: 0.0020 - 891ms/epoch - 2ms/step
# Epoch 79/100
# 494/494 - 1s - loss: 0.0020 - 788ms/epoch - 2ms/step
# Epoch 80/100
# 494/494 - 1s - loss: 0.0019 - 822ms/epoch - 2ms/step
# Epoch 81/100
# 494/494 - 1s - loss: 0.0019 - 798ms/epoch - 2ms/step
# Epoch 82/100
# 494/494 - 1s - loss: 0.0020 - 793ms/epoch - 2ms/step
# Epoch 83/100
# 494/494 - 1s - loss: 0.0019 - 807ms/epoch - 2ms/step
# Epoch 84/100
# 494/494 - 1s - loss: 0.0019 - 785ms/epoch - 2ms/step
# Epoch 85/100
# 494/494 - 1s - loss: 0.0019 - 799ms/epoch - 2ms/step
# Epoch 86/100
# 494/494 - 1s - loss: 0.0019 - 802ms/epoch - 2ms/step
# Epoch 87/100
# 494/494 - 1s - loss: 0.0020 - 794ms/epoch - 2ms/step
# Epoch 88/100
# 494/494 - 1s - loss: 0.0019 - 774ms/epoch - 2ms/step
# Epoch 89/100
# 494/494 - 1s - loss: 0.0019 - 837ms/epoch - 2ms/step
# Epoch 90/100
# 494/494 - 1s - loss: 0.0020 - 903ms/epoch - 2ms/step
# Epoch 91/100
# 494/494 - 1s - loss: 0.0019 - 1s/epoch - 2ms/step
# Epoch 92/100
# 494/494 - 1s - loss: 0.0020 - 1s/epoch - 2ms/step
# Epoch 93/100
# 494/494 - 1s - loss: 0.0019 - 794ms/epoch - 2ms/step
# Epoch 94/100
# 494/494 - 1s - loss: 0.0020 - 812ms/epoch - 2ms/step
# Epoch 95/100
# 494/494 - 1s - loss: 0.0019 - 792ms/epoch - 2ms/step
# Epoch 96/100
# 494/494 - 1s - loss: 0.0019 - 789ms/epoch - 2ms/step
# Epoch 97/100
# 494/494 - 1s - loss: 0.0019 - 800ms/epoch - 2ms/step
# Epoch 98/100
# 494/494 - 1s - loss: 0.0019 - 791ms/epoch - 2ms/step
# Epoch 99/100
# 494/494 - 1s - loss: 0.0019 - 801ms/epoch - 2ms/step
# Epoch 100/100
# 494/494 - 1s - loss: 0.0019 - 810ms/epoch - 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# KO Train Score: 0.22 RMSE
# Finished training model for KO
# Training model for GS...
# Epoch 1/100
# 494/494 - 3s - loss: 0.0579 - 3s/epoch - 6ms/step
# Epoch 2/100
# 494/494 - 1s - loss: 0.0047 - 1s/epoch - 2ms/step
# Epoch 3/100
# 494/494 - 1s - loss: 0.0037 - 1s/epoch - 2ms/step
# Epoch 4/100
# 494/494 - 1s - loss: 0.0034 - 830ms/epoch - 2ms/step
# Epoch 5/100
# 494/494 - 1s - loss: 0.0032 - 818ms/epoch - 2ms/step
# Epoch 6/100
# 494/494 - 1s - loss: 0.0030 - 817ms/epoch - 2ms/step
# Epoch 7/100
# 494/494 - 1s - loss: 0.0027 - 800ms/epoch - 2ms/step
# Epoch 8/100
# 494/494 - 1s - loss: 0.0026 - 836ms/epoch - 2ms/step
# Epoch 9/100
# 494/494 - 1s - loss: 0.0024 - 822ms/epoch - 2ms/step
# Epoch 10/100
# 494/494 - 1s - loss: 0.0022 - 808ms/epoch - 2ms/step
# Epoch 11/100
# 494/494 - 1s - loss: 0.0021 - 810ms/epoch - 2ms/step
# Epoch 12/100
# 494/494 - 1s - loss: 0.0019 - 1s/epoch - 2ms/step
# Epoch 13/100
# 494/494 - 1s - loss: 0.0018 - 1s/epoch - 2ms/step
# Epoch 14/100
# 494/494 - 1s - loss: 0.0017 - 998ms/epoch - 2ms/step
# Epoch 15/100
# 494/494 - 1s - loss: 0.0016 - 1s/epoch - 2ms/step
# Epoch 16/100
# 494/494 - 1s - loss: 0.0016 - 1s/epoch - 2ms/step
# Epoch 17/100
# 494/494 - 1s - loss: 0.0016 - 866ms/epoch - 2ms/step
# Epoch 18/100
# 494/494 - 1s - loss: 0.0015 - 815ms/epoch - 2ms/step
# Epoch 19/100
# 494/494 - 1s - loss: 0.0015 - 844ms/epoch - 2ms/step
# Epoch 20/100
# 494/494 - 1s - loss: 0.0015 - 839ms/epoch - 2ms/step
# Epoch 21/100
# 494/494 - 1s - loss: 0.0015 - 826ms/epoch - 2ms/step
# Epoch 22/100
# 494/494 - 1s - loss: 0.0014 - 826ms/epoch - 2ms/step
# Epoch 23/100
# 494/494 - 1s - loss: 0.0014 - 811ms/epoch - 2ms/step
# Epoch 24/100
# 494/494 - 1s - loss: 0.0013 - 802ms/epoch - 2ms/step
# Epoch 25/100
# 494/494 - 1s - loss: 0.0013 - 831ms/epoch - 2ms/step
# Epoch 26/100
# 494/494 - 1s - loss: 0.0013 - 807ms/epoch - 2ms/step
# Epoch 27/100
# 494/494 - 1s - loss: 0.0013 - 826ms/epoch - 2ms/step
# Epoch 28/100
# 494/494 - 1s - loss: 0.0013 - 797ms/epoch - 2ms/step
# Epoch 29/100
# 494/494 - 1s - loss: 0.0012 - 1s/epoch - 2ms/step
# Epoch 30/100
# 494/494 - 1s - loss: 0.0012 - 1s/epoch - 2ms/step
# Epoch 31/100
# 494/494 - 1s - loss: 0.0012 - 992ms/epoch - 2ms/step
# Epoch 32/100
# 494/494 - 1s - loss: 0.0012 - 804ms/epoch - 2ms/step
# Epoch 33/100
# 494/494 - 1s - loss: 0.0012 - 826ms/epoch - 2ms/step
# Epoch 34/100
# 494/494 - 1s - loss: 0.0012 - 812ms/epoch - 2ms/step
# Epoch 35/100
# 494/494 - 1s - loss: 0.0012 - 820ms/epoch - 2ms/step
# Epoch 36/100
# 494/494 - 1s - loss: 0.0012 - 800ms/epoch - 2ms/step
# Epoch 37/100
# 494/494 - 1s - loss: 0.0012 - 805ms/epoch - 2ms/step
# Epoch 38/100
# 494/494 - 1s - loss: 0.0012 - 900ms/epoch - 2ms/step
# Epoch 39/100
# 494/494 - 1s - loss: 0.0012 - 801ms/epoch - 2ms/step
# Epoch 40/100
# 494/494 - 1s - loss: 0.0012 - 820ms/epoch - 2ms/step
# Epoch 41/100
# 494/494 - 1s - loss: 0.0012 - 804ms/epoch - 2ms/step
# Epoch 42/100
# 494/494 - 1s - loss: 0.0013 - 817ms/epoch - 2ms/step
# Epoch 43/100
# 494/494 - 1s - loss: 0.0012 - 987ms/epoch - 2ms/step
# Epoch 44/100
# 494/494 - 1s - loss: 0.0012 - 1s/epoch - 2ms/step
# Epoch 45/100
# 494/494 - 1s - loss: 0.0012 - 1s/epoch - 2ms/step
# Epoch 46/100
# 494/494 - 1s - loss: 0.0012 - 818ms/epoch - 2ms/step
# Epoch 47/100
# 494/494 - 1s - loss: 0.0011 - 841ms/epoch - 2ms/step
# Epoch 48/100
# 494/494 - 1s - loss: 0.0012 - 810ms/epoch - 2ms/step
# Epoch 49/100
# 494/494 - 1s - loss: 0.0012 - 824ms/epoch - 2ms/step
# Epoch 50/100
# 494/494 - 1s - loss: 0.0012 - 825ms/epoch - 2ms/step
# Epoch 51/100
# 494/494 - 1s - loss: 0.0012 - 808ms/epoch - 2ms/step
# Epoch 52/100
# 494/494 - 1s - loss: 0.0012 - 816ms/epoch - 2ms/step
# Epoch 53/100
# 494/494 - 1s - loss: 0.0011 - 839ms/epoch - 2ms/step
# Epoch 54/100
# 494/494 - 1s - loss: 0.0012 - 819ms/epoch - 2ms/step
# Epoch 55/100
# 494/494 - 1s - loss: 0.0011 - 831ms/epoch - 2ms/step
# Epoch 56/100
# 494/494 - 1s - loss: 0.0011 - 836ms/epoch - 2ms/step
# Epoch 57/100
# 494/494 - 1s - loss: 0.0011 - 880ms/epoch - 2ms/step
# Epoch 58/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 59/100
# 494/494 - 1s - loss: 0.0012 - 1s/epoch - 2ms/step
# Epoch 60/100
# 494/494 - 1s - loss: 0.0012 - 831ms/epoch - 2ms/step
# Epoch 61/100
# 494/494 - 1s - loss: 0.0012 - 830ms/epoch - 2ms/step
# Epoch 62/100
# 494/494 - 1s - loss: 0.0012 - 810ms/epoch - 2ms/step
# Epoch 63/100
# 494/494 - 1s - loss: 0.0012 - 806ms/epoch - 2ms/step
# Epoch 64/100
# 494/494 - 1s - loss: 0.0012 - 822ms/epoch - 2ms/step
# Epoch 65/100
# 494/494 - 1s - loss: 0.0011 - 837ms/epoch - 2ms/step
# Epoch 66/100
# 494/494 - 1s - loss: 0.0011 - 804ms/epoch - 2ms/step
# Epoch 67/100
# 494/494 - 1s - loss: 0.0012 - 822ms/epoch - 2ms/step
# Epoch 68/100
# 494/494 - 1s - loss: 0.0011 - 830ms/epoch - 2ms/step
# Epoch 69/100
# 494/494 - 1s - loss: 0.0011 - 810ms/epoch - 2ms/step
# Epoch 70/100
# 494/494 - 1s - loss: 0.0011 - 816ms/epoch - 2ms/step
# Epoch 71/100
# 494/494 - 1s - loss: 0.0011 - 808ms/epoch - 2ms/step
# Epoch 72/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 73/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 74/100
# 494/494 - 1s - loss: 0.0011 - 986ms/epoch - 2ms/step
# Epoch 75/100
# 494/494 - 1s - loss: 0.0011 - 818ms/epoch - 2ms/step
# Epoch 76/100
# 494/494 - 1s - loss: 0.0011 - 838ms/epoch - 2ms/step
# Epoch 77/100
# 494/494 - 1s - loss: 0.0012 - 809ms/epoch - 2ms/step
# Epoch 78/100
# 494/494 - 1s - loss: 0.0011 - 815ms/epoch - 2ms/step
# Epoch 79/100
# 494/494 - 1s - loss: 0.0011 - 793ms/epoch - 2ms/step
# Epoch 80/100
# 494/494 - 1s - loss: 0.0011 - 808ms/epoch - 2ms/step
# Epoch 81/100
# 494/494 - 1s - loss: 0.0011 - 802ms/epoch - 2ms/step
# Epoch 82/100
# 494/494 - 1s - loss: 0.0011 - 839ms/epoch - 2ms/step
# Epoch 83/100
# 494/494 - 1s - loss: 0.0011 - 826ms/epoch - 2ms/step
# Epoch 84/100
# 494/494 - 1s - loss: 0.0011 - 795ms/epoch - 2ms/step
# Epoch 85/100
# 494/494 - 1s - loss: 0.0011 - 831ms/epoch - 2ms/step
# Epoch 86/100
# 494/494 - 1s - loss: 0.0013 - 928ms/epoch - 2ms/step
# Epoch 87/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 88/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 89/100
# 494/494 - 1s - loss: 0.0011 - 801ms/epoch - 2ms/step
# Epoch 90/100
# 494/494 - 1s - loss: 0.0011 - 807ms/epoch - 2ms/step
# Epoch 91/100
# 494/494 - 1s - loss: 0.0012 - 807ms/epoch - 2ms/step
# Epoch 92/100
# 494/494 - 1s - loss: 0.0011 - 805ms/epoch - 2ms/step
# Epoch 93/100
# 494/494 - 1s - loss: 0.0011 - 824ms/epoch - 2ms/step
# Epoch 94/100
# 494/494 - 1s - loss: 0.0011 - 827ms/epoch - 2ms/step
# Epoch 95/100
# 494/494 - 1s - loss: 0.0011 - 818ms/epoch - 2ms/step
# Epoch 96/100
# 494/494 - 1s - loss: 0.0011 - 810ms/epoch - 2ms/step
# Epoch 97/100
# 494/494 - 1s - loss: 0.0011 - 802ms/epoch - 2ms/step
# Epoch 98/100
# 494/494 - 1s - loss: 0.0011 - 818ms/epoch - 2ms/step
# Epoch 99/100
# 494/494 - 1s - loss: 0.0011 - 807ms/epoch - 2ms/step
# Epoch 100/100
# 494/494 - 1s - loss: 0.0011 - 832ms/epoch - 2ms/step
# 16/16 [==============================] - 1s 3ms/step
# GS Train Score: 2.32 RMSE
# Finished training model for GS
# Training model for HD...
# Epoch 1/100
# 494/494 - 3s - loss: 0.0236 - 3s/epoch - 6ms/step
# Epoch 2/100
# 494/494 - 1s - loss: 0.0032 - 796ms/epoch - 2ms/step
# Epoch 3/100
# 494/494 - 1s - loss: 0.0026 - 785ms/epoch - 2ms/step
# Epoch 4/100
# 494/494 - 1s - loss: 0.0022 - 787ms/epoch - 2ms/step
# Epoch 5/100
# 494/494 - 1s - loss: 0.0020 - 805ms/epoch - 2ms/step
# Epoch 6/100
# 494/494 - 1s - loss: 0.0018 - 805ms/epoch - 2ms/step
# Epoch 7/100
# 494/494 - 1s - loss: 0.0017 - 783ms/epoch - 2ms/step
# Epoch 8/100
# 494/494 - 1s - loss: 0.0016 - 812ms/epoch - 2ms/step
# Epoch 9/100
# 494/494 - 1s - loss: 0.0017 - 785ms/epoch - 2ms/step
# Epoch 10/100
# 494/494 - 1s - loss: 0.0016 - 803ms/epoch - 2ms/step
# Epoch 11/100
# 494/494 - 1s - loss: 0.0016 - 804ms/epoch - 2ms/step
# Epoch 12/100
# 494/494 - 1s - loss: 0.0015 - 1s/epoch - 2ms/step
# Epoch 13/100
# 494/494 - 1s - loss: 0.0015 - 1s/epoch - 2ms/step
# Epoch 14/100
# 494/494 - 1s - loss: 0.0014 - 1s/epoch - 2ms/step
# Epoch 15/100
# 494/494 - 1s - loss: 0.0014 - 825ms/epoch - 2ms/step
# Epoch 16/100
# 494/494 - 1s - loss: 0.0014 - 815ms/epoch - 2ms/step
# Epoch 17/100
# 494/494 - 1s - loss: 0.0014 - 803ms/epoch - 2ms/step
# Epoch 18/100
# 494/494 - 1s - loss: 0.0014 - 818ms/epoch - 2ms/step
# Epoch 19/100
# 494/494 - 1s - loss: 0.0013 - 795ms/epoch - 2ms/step
# Epoch 20/100
# 494/494 - 1s - loss: 0.0013 - 824ms/epoch - 2ms/step
# Epoch 21/100
# 494/494 - 1s - loss: 0.0013 - 817ms/epoch - 2ms/step
# Epoch 22/100
# 494/494 - 1s - loss: 0.0013 - 795ms/epoch - 2ms/step
# Epoch 23/100
# 494/494 - 1s - loss: 0.0013 - 806ms/epoch - 2ms/step
# Epoch 24/100
# 494/494 - 1s - loss: 0.0012 - 780ms/epoch - 2ms/step
# Epoch 25/100
# 494/494 - 1s - loss: 0.0013 - 801ms/epoch - 2ms/step
# Epoch 26/100
# 494/494 - 1s - loss: 0.0013 - 793ms/epoch - 2ms/step
# Epoch 27/100
# 494/494 - 1s - loss: 0.0013 - 1s/epoch - 2ms/step
# Epoch 28/100
# 494/494 - 1s - loss: 0.0013 - 1s/epoch - 2ms/step
# Epoch 29/100
# 494/494 - 1s - loss: 0.0013 - 929ms/epoch - 2ms/step
# Epoch 30/100
# 494/494 - 1s - loss: 0.0012 - 801ms/epoch - 2ms/step
# Epoch 31/100
# 494/494 - 1s - loss: 0.0012 - 816ms/epoch - 2ms/step
# Epoch 32/100
# 494/494 - 1s - loss: 0.0012 - 804ms/epoch - 2ms/step
# Epoch 33/100
# 494/494 - 1s - loss: 0.0011 - 801ms/epoch - 2ms/step
# Epoch 34/100
# 494/494 - 1s - loss: 0.0012 - 794ms/epoch - 2ms/step
# Epoch 35/100
# 494/494 - 1s - loss: 0.0012 - 794ms/epoch - 2ms/step
# Epoch 36/100
# 494/494 - 1s - loss: 0.0012 - 807ms/epoch - 2ms/step
# Epoch 37/100
# 494/494 - 1s - loss: 0.0012 - 801ms/epoch - 2ms/step
# Epoch 38/100
# 494/494 - 1s - loss: 0.0012 - 791ms/epoch - 2ms/step
# Epoch 39/100
# 494/494 - 1s - loss: 0.0011 - 808ms/epoch - 2ms/step
# Epoch 40/100
# 494/494 - 1s - loss: 0.0011 - 799ms/epoch - 2ms/step
# Epoch 41/100
# 494/494 - 1s - loss: 0.0011 - 906ms/epoch - 2ms/step
# Epoch 42/100
# 494/494 - 1s - loss: 0.0012 - 1s/epoch - 2ms/step
# Epoch 43/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 44/100
# 494/494 - 1s - loss: 0.0012 - 812ms/epoch - 2ms/step
# Epoch 45/100
# 494/494 - 1s - loss: 0.0011 - 812ms/epoch - 2ms/step
# Epoch 46/100
# 494/494 - 1s - loss: 0.0012 - 793ms/epoch - 2ms/step
# Epoch 47/100
# 494/494 - 1s - loss: 0.0011 - 780ms/epoch - 2ms/step
# Epoch 48/100
# 494/494 - 1s - loss: 0.0011 - 812ms/epoch - 2ms/step
# Epoch 49/100
# 494/494 - 1s - loss: 0.0011 - 810ms/epoch - 2ms/step
# Epoch 50/100
# 494/494 - 1s - loss: 0.0011 - 806ms/epoch - 2ms/step
# Epoch 51/100
# 494/494 - 1s - loss: 0.0012 - 798ms/epoch - 2ms/step
# Epoch 52/100
# 494/494 - 1s - loss: 0.0011 - 790ms/epoch - 2ms/step
# Epoch 53/100
# 494/494 - 1s - loss: 0.0011 - 796ms/epoch - 2ms/step
# Epoch 54/100
# 494/494 - 1s - loss: 0.0011 - 800ms/epoch - 2ms/step
# Epoch 55/100
# 494/494 - 1s - loss: 0.0011 - 800ms/epoch - 2ms/step
# Epoch 56/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 57/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 58/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 59/100
# 494/494 - 1s - loss: 0.0011 - 821ms/epoch - 2ms/step
# Epoch 60/100
# 494/494 - 1s - loss: 0.0011 - 795ms/epoch - 2ms/step
# Epoch 61/100
# 494/494 - 1s - loss: 0.0011 - 776ms/epoch - 2ms/step
# Epoch 62/100
# 494/494 - 1s - loss: 0.0011 - 808ms/epoch - 2ms/step
# Epoch 63/100
# 494/494 - 1s - loss: 0.0011 - 805ms/epoch - 2ms/step
# Epoch 64/100
# 494/494 - 1s - loss: 0.0011 - 801ms/epoch - 2ms/step
# Epoch 65/100
# 494/494 - 1s - loss: 0.0011 - 798ms/epoch - 2ms/step
# Epoch 66/100
# 494/494 - 1s - loss: 0.0011 - 797ms/epoch - 2ms/step
# Epoch 67/100
# 494/494 - 1s - loss: 0.0011 - 827ms/epoch - 2ms/step
# Epoch 68/100
# 494/494 - 1s - loss: 0.0011 - 795ms/epoch - 2ms/step
# Epoch 69/100
# 494/494 - 1s - loss: 0.0011 - 817ms/epoch - 2ms/step
# Epoch 70/100
# 494/494 - 1s - loss: 0.0010 - 833ms/epoch - 2ms/step
# Epoch 71/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 3ms/step
# Epoch 72/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 73/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 74/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 75/100
# 494/494 - 1s - loss: 0.0011 - 877ms/epoch - 2ms/step
# Epoch 76/100
# 494/494 - 1s - loss: 0.0011 - 816ms/epoch - 2ms/step
# Epoch 77/100
# 494/494 - 1s - loss: 0.0011 - 820ms/epoch - 2ms/step
# Epoch 78/100
# 494/494 - 1s - loss: 0.0010 - 800ms/epoch - 2ms/step
# Epoch 79/100
# 494/494 - 1s - loss: 0.0010 - 822ms/epoch - 2ms/step
# Epoch 80/100
# 494/494 - 1s - loss: 0.0011 - 804ms/epoch - 2ms/step
# Epoch 81/100
# 494/494 - 1s - loss: 0.0011 - 806ms/epoch - 2ms/step
# Epoch 82/100
# 494/494 - 1s - loss: 0.0010 - 805ms/epoch - 2ms/step
# Epoch 83/100
# 494/494 - 1s - loss: 0.0011 - 800ms/epoch - 2ms/step
# Epoch 84/100
# 494/494 - 1s - loss: 0.0011 - 787ms/epoch - 2ms/step
# Epoch 85/100
# 494/494 - 1s - loss: 0.0011 - 793ms/epoch - 2ms/step
# Epoch 86/100
# 494/494 - 1s - loss: 0.0011 - 780ms/epoch - 2ms/step
# Epoch 87/100
# 494/494 - 1s - loss: 0.0011 - 968ms/epoch - 2ms/step
# Epoch 88/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 89/100
# 494/494 - 1s - loss: 0.0010 - 1s/epoch - 2ms/step
# Epoch 90/100
# 494/494 - 1s - loss: 0.0011 - 793ms/epoch - 2ms/step
# Epoch 91/100
# 494/494 - 1s - loss: 0.0010 - 803ms/epoch - 2ms/step
# Epoch 92/100
# 494/494 - 1s - loss: 0.0011 - 821ms/epoch - 2ms/step
# Epoch 93/100
# 494/494 - 1s - loss: 0.0010 - 799ms/epoch - 2ms/step
# Epoch 94/100
# 494/494 - 1s - loss: 0.0011 - 792ms/epoch - 2ms/step
# Epoch 95/100
# 494/494 - 1s - loss: 9.6486e-04 - 808ms/epoch - 2ms/step
# Epoch 96/100
# 494/494 - 1s - loss: 0.0012 - 829ms/epoch - 2ms/step
# Epoch 97/100
# 494/494 - 1s - loss: 0.0011 - 805ms/epoch - 2ms/step
# Epoch 98/100
# 494/494 - 1s - loss: 0.0011 - 810ms/epoch - 2ms/step
# Epoch 99/100
# 494/494 - 1s - loss: 0.0011 - 824ms/epoch - 2ms/step
# Epoch 100/100
# 494/494 - 1s - loss: 0.0011 - 796ms/epoch - 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# HD Train Score: 1.82 RMSE
# Finished training model for HD
# Training model for HON...
# Epoch 1/100
# 494/494 - 3s - loss: 0.0515 - 3s/epoch - 7ms/step
# Epoch 2/100
# 494/494 - 1s - loss: 0.0038 - 792ms/epoch - 2ms/step
# Epoch 3/100
# 494/494 - 1s - loss: 0.0028 - 809ms/epoch - 2ms/step
# Epoch 4/100
# 494/494 - 1s - loss: 0.0026 - 776ms/epoch - 2ms/step
# Epoch 5/100
# 494/494 - 1s - loss: 0.0024 - 794ms/epoch - 2ms/step
# Epoch 6/100
# 494/494 - 1s - loss: 0.0021 - 790ms/epoch - 2ms/step
# Epoch 7/100
# 494/494 - 1s - loss: 0.0018 - 799ms/epoch - 2ms/step
# Epoch 8/100
# 494/494 - 1s - loss: 0.0016 - 795ms/epoch - 2ms/step
# Epoch 9/100
# 494/494 - 1s - loss: 0.0017 - 809ms/epoch - 2ms/step
# Epoch 10/100
# 494/494 - 1s - loss: 0.0015 - 821ms/epoch - 2ms/step
# Epoch 11/100
# 494/494 - 1s - loss: 0.0015 - 793ms/epoch - 2ms/step
# Epoch 12/100
# 494/494 - 1s - loss: 0.0015 - 796ms/epoch - 2ms/step
# Epoch 13/100
# 494/494 - 1s - loss: 0.0014 - 994ms/epoch - 2ms/step
# Epoch 14/100
# 494/494 - 1s - loss: 0.0014 - 1s/epoch - 2ms/step
# Epoch 15/100
# 494/494 - 1s - loss: 0.0014 - 1s/epoch - 2ms/step
# Epoch 16/100
# 494/494 - 1s - loss: 0.0014 - 812ms/epoch - 2ms/step
# Epoch 17/100
# 494/494 - 1s - loss: 0.0014 - 806ms/epoch - 2ms/step
# Epoch 18/100
# 494/494 - 1s - loss: 0.0013 - 795ms/epoch - 2ms/step
# Epoch 19/100
# 494/494 - 1s - loss: 0.0013 - 796ms/epoch - 2ms/step
# Epoch 20/100
# 494/494 - 1s - loss: 0.0013 - 815ms/epoch - 2ms/step
# Epoch 21/100
# 494/494 - 1s - loss: 0.0013 - 829ms/epoch - 2ms/step
# Epoch 22/100
# 494/494 - 1s - loss: 0.0013 - 824ms/epoch - 2ms/step
# Epoch 23/100
# 494/494 - 1s - loss: 0.0012 - 806ms/epoch - 2ms/step
# Epoch 24/100
# 494/494 - 1s - loss: 0.0013 - 792ms/epoch - 2ms/step
# Epoch 25/100
# 494/494 - 1s - loss: 0.0013 - 804ms/epoch - 2ms/step
# Epoch 26/100
# 494/494 - 1s - loss: 0.0013 - 798ms/epoch - 2ms/step
# Epoch 27/100
# 494/494 - 1s - loss: 0.0012 - 796ms/epoch - 2ms/step
# Epoch 28/100
# 494/494 - 1s - loss: 0.0012 - 1s/epoch - 2ms/step
# Epoch 29/100
# 494/494 - 1s - loss: 0.0012 - 1s/epoch - 2ms/step
# Epoch 30/100
# 494/494 - 1s - loss: 0.0013 - 889ms/epoch - 2ms/step
# Epoch 31/100
# 494/494 - 1s - loss: 0.0012 - 800ms/epoch - 2ms/step
# Epoch 32/100
# 494/494 - 1s - loss: 0.0012 - 796ms/epoch - 2ms/step
# Epoch 33/100
# 494/494 - 1s - loss: 0.0012 - 828ms/epoch - 2ms/step
# Epoch 34/100
# 494/494 - 1s - loss: 0.0012 - 805ms/epoch - 2ms/step
# Epoch 35/100
# 494/494 - 1s - loss: 0.0012 - 812ms/epoch - 2ms/step
# Epoch 36/100
# 494/494 - 1s - loss: 0.0012 - 791ms/epoch - 2ms/step
# Epoch 37/100
# 494/494 - 1s - loss: 0.0012 - 787ms/epoch - 2ms/step
# Epoch 38/100
# 494/494 - 1s - loss: 0.0011 - 784ms/epoch - 2ms/step
# Epoch 39/100
# 494/494 - 1s - loss: 0.0012 - 797ms/epoch - 2ms/step
# Epoch 40/100
# 494/494 - 1s - loss: 0.0011 - 794ms/epoch - 2ms/step
# Epoch 41/100
# ...
# Epoch 68/100
# 494/494 - 1s - loss: 0.0016 - 1s/epoch - 2ms/step
# Epoch 69/100
# 494/494 - 1s - loss: 0.0016 - 1s/epoch - 2ms/step
# Epoch 70/100
# 494/494 - 1s - loss: 0.0017 - 889ms/epoch - 2ms/step
# Epoch 71/100
# 494/494 - 1s - loss: 0.0017 - 797ms/epoch - 2ms/step
# Epoch 72/100
# 494/494 - 1s - loss: 0.0017 - 813ms/epoch - 2ms/step
# Epoch 73/100
# 494/494 - 1s - loss: 0.0016 - 859ms/epoch - 2ms/step
# Epoch 74/100
# 494/494 - 1s - loss: 0.0016 - 1s/epoch - 2ms/step
# Epoch 75/100
# 494/494 - 1s - loss: 0.0016 - 1s/epoch - 2ms/step
# Epoch 76/100
# 494/494 - 1s - loss: 0.0016 - 877ms/epoch - 2ms/step
# Epoch 77/100
# 494/494 - 1s - loss: 0.0016 - 798ms/epoch - 2ms/step
# Epoch 78/100
# 494/494 - 1s - loss: 0.0016 - 803ms/epoch - 2ms/step
# Epoch 79/100
# 494/494 - 1s - loss: 0.0016 - 821ms/epoch - 2ms/step
# Epoch 80/100
# 494/494 - 1s - loss: 0.0016 - 803ms/epoch - 2ms/step
# Epoch 81/100
# 494/494 - 1s - loss: 0.0016 - 809ms/epoch - 2ms/step
# Epoch 82/100
# 494/494 - 1s - loss: 0.0016 - 805ms/epoch - 2ms/step
# Epoch 83/100
# 494/494 - 1s - loss: 0.0016 - 789ms/epoch - 2ms/step
# Epoch 84/100
# 494/494 - 1s - loss: 0.0016 - 815ms/epoch - 2ms/step
# Epoch 85/100
# 494/494 - 1s - loss: 0.0016 - 796ms/epoch - 2ms/step
# Epoch 86/100
# 494/494 - 1s - loss: 0.0016 - 811ms/epoch - 2ms/step
# Epoch 87/100
# 494/494 - 1s - loss: 0.0016 - 807ms/epoch - 2ms/step
# Epoch 88/100
# 494/494 - 1s - loss: 0.0016 - 934ms/epoch - 2ms/step
# Epoch 89/100
# 494/494 - 1s - loss: 0.0016 - 1s/epoch - 2ms/step
# Epoch 90/100
# 494/494 - 1s - loss: 0.0016 - 1s/epoch - 2ms/step
# Epoch 91/100
# 494/494 - 1s - loss: 0.0016 - 803ms/epoch - 2ms/step
# Epoch 92/100
# 494/494 - 1s - loss: 0.0016 - 808ms/epoch - 2ms/step
# Epoch 93/100
# 494/494 - 1s - loss: 0.0016 - 808ms/epoch - 2ms/step
# Epoch 94/100
# 494/494 - 1s - loss: 0.0016 - 820ms/epoch - 2ms/step
# Epoch 95/100
# 494/494 - 1s - loss: 0.0016 - 803ms/epoch - 2ms/step
# Epoch 96/100
# 494/494 - 1s - loss: 0.0015 - 816ms/epoch - 2ms/step
# Epoch 97/100
# 494/494 - 1s - loss: 0.0016 - 801ms/epoch - 2ms/step
# Epoch 98/100
# 494/494 - 1s - loss: 0.0015 - 796ms/epoch - 2ms/step
# Epoch 99/100
# 494/494 - 1s - loss: 0.0016 - 807ms/epoch - 2ms/step
# Epoch 100/100
# 494/494 - 1s - loss: 0.0016 - 796ms/epoch - 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# WMT Train Score: 0.56 RMSE
# Finished training model for WMT
# Training model for DIS...
# Epoch 1/100
# 494/494 - 3s - loss: 0.0145 - 3s/epoch - 5ms/step
# Epoch 2/100
# 494/494 - 1s - loss: 0.0023 - 795ms/epoch - 2ms/step
# Epoch 3/100
# 494/494 - 1s - loss: 0.0021 - 796ms/epoch - 2ms/step
# Epoch 4/100
# 494/494 - 1s - loss: 0.0019 - 1s/epoch - 2ms/step
# Epoch 5/100
# 494/494 - 1s - loss: 0.0017 - 1s/epoch - 2ms/step
# Epoch 6/100
# 494/494 - 1s - loss: 0.0016 - 982ms/epoch - 2ms/step
# Epoch 7/100
# 494/494 - 1s - loss: 0.0015 - 788ms/epoch - 2ms/step
# Epoch 8/100
# 494/494 - 1s - loss: 0.0014 - 789ms/epoch - 2ms/step
# Epoch 9/100
# 494/494 - 1s - loss: 0.0013 - 794ms/epoch - 2ms/step
# Epoch 10/100
# 494/494 - 1s - loss: 0.0013 - 790ms/epoch - 2ms/step
# Epoch 11/100
# 494/494 - 1s - loss: 0.0012 - 782ms/epoch - 2ms/step
# Epoch 12/100
# 494/494 - 1s - loss: 0.0012 - 804ms/epoch - 2ms/step
# Epoch 13/100
# 494/494 - 1s - loss: 0.0011 - 780ms/epoch - 2ms/step
# Epoch 14/100
# 494/494 - 1s - loss: 0.0011 - 778ms/epoch - 2ms/step
# Epoch 15/100
# 494/494 - 1s - loss: 0.0010 - 808ms/epoch - 2ms/step
# Epoch 16/100
# 494/494 - 1s - loss: 0.0010 - 780ms/epoch - 2ms/step
# Epoch 17/100
# 494/494 - 1s - loss: 0.0010 - 782ms/epoch - 2ms/step
# Epoch 18/100
# 494/494 - 1s - loss: 9.7120e-04 - 784ms/epoch - 2ms/step
# Epoch 19/100
# 494/494 - 1s - loss: 9.7341e-04 - 1s/epoch - 2ms/step
# Epoch 20/100
# 494/494 - 1s - loss: 9.0649e-04 - 1s/epoch - 2ms/step
# Epoch 21/100
# 494/494 - 1s - loss: 9.0785e-04 - 970ms/epoch - 2ms/step
# Epoch 22/100
# 494/494 - 1s - loss: 9.0266e-04 - 793ms/epoch - 2ms/step
# Epoch 23/100
# 494/494 - 1s - loss: 8.6152e-04 - 802ms/epoch - 2ms/step
# Epoch 24/100
# 494/494 - 1s - loss: 8.3923e-04 - 795ms/epoch - 2ms/step
# Epoch 25/100
# 494/494 - 1s - loss: 8.7645e-04 - 808ms/epoch - 2ms/step
# Epoch 26/100
# 494/494 - 1s - loss: 8.8776e-04 - 786ms/epoch - 2ms/step
# Epoch 27/100
# 494/494 - 1s - loss: 8.4088e-04 - 788ms/epoch - 2ms/step
# Epoch 28/100
# 494/494 - 1s - loss: 8.6206e-04 - 799ms/epoch - 2ms/step
# Epoch 29/100
# 494/494 - 1s - loss: 8.0069e-04 - 790ms/epoch - 2ms/step
# Epoch 30/100
# 494/494 - 1s - loss: 8.0951e-04 - 792ms/epoch - 2ms/step
# Epoch 31/100
# 494/494 - 1s - loss: 7.9890e-04 - 781ms/epoch - 2ms/step
# Epoch 32/100
# 494/494 - 1s - loss: 7.7557e-04 - 804ms/epoch - 2ms/step
# Epoch 33/100
# 494/494 - 1s - loss: 8.0675e-04 - 799ms/epoch - 2ms/step
# Epoch 34/100
# 494/494 - 1s - loss: 7.5862e-04 - 1s/epoch - 2ms/step
# Epoch 35/100
# 494/494 - 1s - loss: 7.4746e-04 - 1s/epoch - 2ms/step
# Epoch 36/100
# 494/494 - 1s - loss: 7.7852e-04 - 920ms/epoch - 2ms/step
# Epoch 37/100
# 494/494 - 1s - loss: 7.3839e-04 - 797ms/epoch - 2ms/step
# Epoch 38/100
# 494/494 - 1s - loss: 7.4668e-04 - 809ms/epoch - 2ms/step
# Epoch 39/100
# 494/494 - 1s - loss: 7.4035e-04 - 791ms/epoch - 2ms/step
# Epoch 40/100
# 494/494 - 1s - loss: 7.6900e-04 - 787ms/epoch - 2ms/step
# Epoch 41/100
# 494/494 - 1s - loss: 7.3675e-04 - 790ms/epoch - 2ms/step
# Epoch 42/100
# 494/494 - 1s - loss: 7.4994e-04 - 799ms/epoch - 2ms/step
# Epoch 43/100
# 494/494 - 1s - loss: 7.2123e-04 - 793ms/epoch - 2ms/step
# Epoch 44/100
# 494/494 - 1s - loss: 7.5028e-04 - 802ms/epoch - 2ms/step
# Epoch 45/100
# 494/494 - 1s - loss: 7.0067e-04 - 802ms/epoch - 2ms/step
# Epoch 46/100
# 494/494 - 1s - loss: 7.3725e-04 - 779ms/epoch - 2ms/step
# Epoch 47/100
# 494/494 - 1s - loss: 7.4238e-04 - 798ms/epoch - 2ms/step
# Epoch 48/100
# 494/494 - 1s - loss: 7.0897e-04 - 828ms/epoch - 2ms/step
# Epoch 49/100
# 494/494 - 1s - loss: 7.1852e-04 - 1s/epoch - 2ms/step
# Epoch 50/100
# 494/494 - 1s - loss: 7.2624e-04 - 1s/epoch - 2ms/step
# Epoch 51/100
# 494/494 - 1s - loss: 7.6139e-04 - 867ms/epoch - 2ms/step
# Epoch 52/100
# 494/494 - 1s - loss: 6.8265e-04 - 1s/epoch - 2ms/step
# Epoch 53/100
# 494/494 - 1s - loss: 7.0517e-04 - 1s/epoch - 2ms/step
# Epoch 54/100
# 494/494 - 1s - loss: 7.1613e-04 - 946ms/epoch - 2ms/step
# Epoch 55/100
# 494/494 - 1s - loss: 7.0396e-04 - 802ms/epoch - 2ms/step
# Epoch 56/100
# 494/494 - 1s - loss: 7.3666e-04 - 796ms/epoch - 2ms/step
# Epoch 57/100
# 494/494 - 1s - loss: 6.8167e-04 - 804ms/epoch - 2ms/step
# Epoch 58/100
# 494/494 - 1s - loss: 7.3691e-04 - 818ms/epoch - 2ms/step
# Epoch 59/100
# 494/494 - 1s - loss: 6.8675e-04 - 784ms/epoch - 2ms/step
# Epoch 60/100
# 494/494 - 1s - loss: 7.1533e-04 - 784ms/epoch - 2ms/step
# Epoch 61/100
# 494/494 - 1s - loss: 6.6672e-04 - 790ms/epoch - 2ms/step
# Epoch 62/100
# 494/494 - 1s - loss: 7.0120e-04 - 876ms/epoch - 2ms/step
# Epoch 63/100
# 494/494 - 1s - loss: 6.8291e-04 - 1s/epoch - 2ms/step
# Epoch 64/100
# 494/494 - 1s - loss: 6.7813e-04 - 1s/epoch - 2ms/step
# Epoch 65/100
# 494/494 - 1s - loss: 7.1168e-04 - 816ms/epoch - 2ms/step
# Epoch 66/100
# 494/494 - 1s - loss: 6.6293e-04 - 807ms/epoch - 2ms/step
# Epoch 67/100
# 494/494 - 1s - loss: 6.7276e-04 - 835ms/epoch - 2ms/step
# Epoch 68/100
# 494/494 - 1s - loss: 6.9917e-04 - 797ms/epoch - 2ms/step
# Epoch 69/100
# 494/494 - 1s - loss: 7.2137e-04 - 802ms/epoch - 2ms/step
# Epoch 70/100
# 494/494 - 1s - loss: 6.8791e-04 - 805ms/epoch - 2ms/step
# Epoch 71/100
# 494/494 - 1s - loss: 6.9938e-04 - 797ms/epoch - 2ms/step
# Epoch 72/100
# 494/494 - 1s - loss: 6.8305e-04 - 793ms/epoch - 2ms/step
# Epoch 73/100
# 494/494 - 1s - loss: 6.5758e-04 - 797ms/epoch - 2ms/step
# Epoch 74/100
# 494/494 - 1s - loss: 6.6521e-04 - 785ms/epoch - 2ms/step
# Epoch 75/100
# 494/494 - 1s - loss: 6.1996e-04 - 794ms/epoch - 2ms/step
# Epoch 76/100
# 494/494 - 1s - loss: 6.6445e-04 - 787ms/epoch - 2ms/step
# Epoch 77/100
# 494/494 - 1s - loss: 7.0609e-04 - 970ms/epoch - 2ms/step
# Epoch 78/100
# 494/494 - 1s - loss: 6.5472e-04 - 1s/epoch - 2ms/step
# Epoch 79/100
# 494/494 - 1s - loss: 6.9031e-04 - 1s/epoch - 2ms/step
# Epoch 80/100
# 494/494 - 1s - loss: 6.5279e-04 - 813ms/epoch - 2ms/step
# Epoch 81/100
# 494/494 - 1s - loss: 6.7761e-04 - 794ms/epoch - 2ms/step
# Epoch 82/100
# 494/494 - 1s - loss: 7.0025e-04 - 808ms/epoch - 2ms/step
# Epoch 83/100
# 494/494 - 1s - loss: 6.8202e-04 - 783ms/epoch - 2ms/step
# Epoch 84/100
# 494/494 - 1s - loss: 6.8467e-04 - 782ms/epoch - 2ms/step
# Epoch 85/100
# 494/494 - 1s - loss: 6.6342e-04 - 790ms/epoch - 2ms/step
# Epoch 86/100
# 494/494 - 1s - loss: 6.8502e-04 - 788ms/epoch - 2ms/step
# Epoch 87/100
# 494/494 - 1s - loss: 7.2243e-04 - 770ms/epoch - 2ms/step
# Epoch 88/100
# 494/494 - 1s - loss: 6.9596e-04 - 798ms/epoch - 2ms/step
# Epoch 89/100
# 494/494 - 1s - loss: 6.7216e-04 - 800ms/epoch - 2ms/step
# Epoch 90/100
# 494/494 - 1s - loss: 6.6123e-04 - 778ms/epoch - 2ms/step
# Epoch 91/100
# 494/494 - 1s - loss: 6.8837e-04 - 796ms/epoch - 2ms/step
# Epoch 92/100
# 494/494 - 1s - loss: 6.7704e-04 - 1s/epoch - 2ms/step
# Epoch 93/100
# 494/494 - 1s - loss: 6.8619e-04 - 1s/epoch - 2ms/step
# Epoch 94/100
# 494/494 - 1s - loss: 6.4633e-04 - 1s/epoch - 2ms/step
# Epoch 95/100
# 494/494 - 1s - loss: 6.3110e-04 - 790ms/epoch - 2ms/step
# Epoch 96/100
# 494/494 - 1s - loss: 6.7297e-04 - 788ms/epoch - 2ms/step
# Epoch 97/100
# 494/494 - 1s - loss: 6.7340e-04 - 793ms/epoch - 2ms/step
# Epoch 98/100
# 494/494 - 1s - loss: 6.6035e-04 - 779ms/epoch - 2ms/step
# Epoch 99/100
# 494/494 - 1s - loss: 6.8518e-04 - 787ms/epoch - 2ms/step
# Epoch 100/100
# 494/494 - 1s - loss: 6.7961e-04 - 806ms/epoch - 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# DIS Train Score: 0.64 RMSE
# Finished training model for DIS
# Training model for DOW...
# Epoch 1/100
# 494/494 - 3s - loss: 0.1061 - 3s/epoch - 5ms/step
# Epoch 2/100
# 494/494 - 1s - loss: 0.0054 - 788ms/epoch - 2ms/step
# Epoch 3/100
# 494/494 - 1s - loss: 0.0033 - 787ms/epoch - 2ms/step
# Epoch 4/100
# 494/494 - 1s - loss: 0.0028 - 793ms/epoch - 2ms/step
# Epoch 5/100
# 494/494 - 1s - loss: 0.0025 - 800ms/epoch - 2ms/step
# Epoch 6/100
# 494/494 - 1s - loss: 0.0023 - 850ms/epoch - 2ms/step
# Epoch 7/100
# 494/494 - 1s - loss: 0.0020 - 1s/epoch - 2ms/step
# Epoch 8/100
# 494/494 - 1s - loss: 0.0019 - 1s/epoch - 2ms/step
# Epoch 9/100
# 494/494 - 1s - loss: 0.0017 - 904ms/epoch - 2ms/step
# Epoch 10/100
# 494/494 - 1s - loss: 0.0017 - 799ms/epoch - 2ms/step
# Epoch 11/100
# 494/494 - 1s - loss: 0.0016 - 806ms/epoch - 2ms/step
# Epoch 12/100
# 494/494 - 1s - loss: 0.0015 - 802ms/epoch - 2ms/step
# Epoch 13/100
# 494/494 - 1s - loss: 0.0015 - 805ms/epoch - 2ms/step
# Epoch 14/100
# 494/494 - 1s - loss: 0.0015 - 825ms/epoch - 2ms/step
# Epoch 15/100
# 494/494 - 1s - loss: 0.0015 - 820ms/epoch - 2ms/step
# Epoch 16/100
# 494/494 - 1s - loss: 0.0014 - 811ms/epoch - 2ms/step
# Epoch 17/100
# 494/494 - 1s - loss: 0.0014 - 784ms/epoch - 2ms/step
# Epoch 18/100
# 494/494 - 1s - loss: 0.0014 - 811ms/epoch - 2ms/step
# Epoch 19/100
# 494/494 - 1s - loss: 0.0015 - 798ms/epoch - 2ms/step
# Epoch 20/100
# 494/494 - 1s - loss: 0.0014 - 797ms/epoch - 2ms/step
# Epoch 21/100
# 494/494 - 1s - loss: 0.0014 - 938ms/epoch - 2ms/step
# Epoch 22/100
# 494/494 - 1s - loss: 0.0014 - 1s/epoch - 2ms/step
# Epoch 23/100
# 494/494 - 1s - loss: 0.0013 - 1s/epoch - 2ms/step
# Epoch 24/100
# 494/494 - 1s - loss: 0.0013 - 811ms/epoch - 2ms/step
# Epoch 25/100
# 494/494 - 1s - loss: 0.0013 - 814ms/epoch - 2ms/step
# Epoch 26/100
# 494/494 - 1s - loss: 0.0013 - 783ms/epoch - 2ms/step
# Epoch 27/100
# 494/494 - 1s - loss: 0.0013 - 801ms/epoch - 2ms/step
# Epoch 28/100
# 494/494 - 1s - loss: 0.0013 - 805ms/epoch - 2ms/step
# Epoch 29/100
# 494/494 - 1s - loss: 0.0013 - 814ms/epoch - 2ms/step
# Epoch 30/100
# 494/494 - 1s - loss: 0.0013 - 792ms/epoch - 2ms/step
# Epoch 31/100
# 494/494 - 1s - loss: 0.0013 - 797ms/epoch - 2ms/step
# Epoch 32/100
# 494/494 - 1s - loss: 0.0013 - 821ms/epoch - 2ms/step
# Epoch 33/100
# 494/494 - 1s - loss: 0.0012 - 797ms/epoch - 2ms/step
# Epoch 34/100
# 494/494 - 1s - loss: 0.0013 - 790ms/epoch - 2ms/step
# Epoch 35/100
# 494/494 - 1s - loss: 0.0012 - 794ms/epoch - 2ms/step
# Epoch 36/100
# 494/494 - 1s - loss: 0.0012 - 1s/epoch - 2ms/step
# Epoch 37/100
# 494/494 - 1s - loss: 0.0013 - 1s/epoch - 2ms/step
# Epoch 38/100
# 494/494 - 1s - loss: 0.0013 - 1s/epoch - 2ms/step
# Epoch 39/100
# 494/494 - 1s - loss: 0.0012 - 1s/epoch - 2ms/step
# Epoch 40/100
# 494/494 - 1s - loss: 0.0012 - 1s/epoch - 2ms/step
# Epoch 41/100
# 494/494 - 1s - loss: 0.0012 - 795ms/epoch - 2ms/step
# Epoch 42/100
# 494/494 - 1s - loss: 0.0012 - 786ms/epoch - 2ms/step
# Epoch 43/100
# 494/494 - 1s - loss: 0.0012 - 825ms/epoch - 2ms/step
# Epoch 44/100
# 494/494 - 1s - loss: 0.0012 - 781ms/epoch - 2ms/step
# Epoch 45/100
# 494/494 - 1s - loss: 0.0013 - 783ms/epoch - 2ms/step
# Epoch 46/100
# 494/494 - 1s - loss: 0.0012 - 784ms/epoch - 2ms/step
# Epoch 47/100
# 494/494 - 1s - loss: 0.0012 - 790ms/epoch - 2ms/step
# Epoch 48/100
# 494/494 - 1s - loss: 0.0012 - 800ms/epoch - 2ms/step
# Epoch 49/100
# 494/494 - 1s - loss: 0.0012 - 813ms/epoch - 2ms/step
# Epoch 50/100
# 494/494 - 1s - loss: 0.0011 - 795ms/epoch - 2ms/step
# Epoch 51/100
# 494/494 - 1s - loss: 0.0012 - 795ms/epoch - 2ms/step
# Epoch 52/100
# 494/494 - 1s - loss: 0.0012 - 788ms/epoch - 2ms/step
# Epoch 53/100
# 494/494 - 1s - loss: 0.0012 - 1s/epoch - 2ms/step
# Epoch 54/100
# 494/494 - 1s - loss: 0.0012 - 1s/epoch - 2ms/step
# Epoch 55/100
# 494/494 - 1s - loss: 0.0012 - 978ms/epoch - 2ms/step
# Epoch 56/100
# 494/494 - 1s - loss: 0.0012 - 807ms/epoch - 2ms/step
# Epoch 57/100
# 494/494 - 1s - loss: 0.0011 - 803ms/epoch - 2ms/step
# Epoch 58/100
# 494/494 - 1s - loss: 0.0012 - 797ms/epoch - 2ms/step
# Epoch 59/100
# 494/494 - 1s - loss: 0.0011 - 783ms/epoch - 2ms/step
# Epoch 60/100
# 494/494 - 1s - loss: 0.0012 - 788ms/epoch - 2ms/step
# Epoch 61/100
# 494/494 - 1s - loss: 0.0012 - 797ms/epoch - 2ms/step
# Epoch 62/100
# 494/494 - 1s - loss: 0.0012 - 805ms/epoch - 2ms/step
# Epoch 63/100
# 494/494 - 1s - loss: 0.0012 - 798ms/epoch - 2ms/step
# Epoch 64/100
# 494/494 - 1s - loss: 0.0011 - 769ms/epoch - 2ms/step
# Epoch 65/100
# 494/494 - 1s - loss: 0.0012 - 790ms/epoch - 2ms/step
# Epoch 66/100
# 494/494 - 1s - loss: 0.0011 - 799ms/epoch - 2ms/step
# Epoch 67/100
# 494/494 - 1s - loss: 0.0012 - 815ms/epoch - 2ms/step
# Epoch 68/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 69/100
# 494/494 - 1s - loss: 0.0012 - 1s/epoch - 2ms/step
# Epoch 70/100
# 494/494 - 1s - loss: 0.0011 - 910ms/epoch - 2ms/step
# Epoch 71/100
# 494/494 - 1s - loss: 0.0011 - 807ms/epoch - 2ms/step
# Epoch 72/100
# 494/494 - 1s - loss: 0.0012 - 798ms/epoch - 2ms/step
# Epoch 73/100
# 494/494 - 1s - loss: 0.0011 - 790ms/epoch - 2ms/step
# Epoch 74/100
# 494/494 - 1s - loss: 0.0011 - 819ms/epoch - 2ms/step
# Epoch 75/100
# 494/494 - 1s - loss: 0.0011 - 821ms/epoch - 2ms/step
# Epoch 76/100
# 494/494 - 1s - loss: 0.0011 - 798ms/epoch - 2ms/step
# Epoch 77/100
# 494/494 - 1s - loss: 0.0012 - 798ms/epoch - 2ms/step
# Epoch 78/100
# 494/494 - 1s - loss: 0.0011 - 822ms/epoch - 2ms/step
# Epoch 79/100
# 494/494 - 1s - loss: 0.0011 - 792ms/epoch - 2ms/step
# Epoch 80/100
# 494/494 - 1s - loss: 0.0011 - 798ms/epoch - 2ms/step
# Epoch 81/100
# 494/494 - 1s - loss: 0.0011 - 762ms/epoch - 2ms/step
# Epoch 82/100
# 494/494 - 1s - loss: 0.0011 - 847ms/epoch - 2ms/step
# Epoch 83/100
# 494/494 - 1s - loss: 0.0012 - 1s/epoch - 2ms/step
# Epoch 84/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 85/100
# 494/494 - 1s - loss: 0.0011 - 834ms/epoch - 2ms/step
# Epoch 86/100
# 494/494 - 1s - loss: 0.0012 - 793ms/epoch - 2ms/step
# Epoch 87/100
# 494/494 - 1s - loss: 0.0011 - 778ms/epoch - 2ms/step
# Epoch 88/100
# 494/494 - 1s - loss: 0.0011 - 786ms/epoch - 2ms/step
# Epoch 89/100
# 494/494 - 1s - loss: 0.0012 - 774ms/epoch - 2ms/step
# Epoch 90/100
# 494/494 - 1s - loss: 0.0012 - 816ms/epoch - 2ms/step
# Epoch 91/100
# 494/494 - 1s - loss: 0.0011 - 790ms/epoch - 2ms/step
# Epoch 92/100
# 494/494 - 1s - loss: 0.0011 - 785ms/epoch - 2ms/step
# Epoch 93/100
# 494/494 - 1s - loss: 0.0011 - 779ms/epoch - 2ms/step
# Epoch 94/100
# 494/494 - 1s - loss: 0.0011 - 787ms/epoch - 2ms/step
# Epoch 95/100
# 494/494 - 1s - loss: 0.0011 - 801ms/epoch - 2ms/step
# Epoch 96/100
# 494/494 - 1s - loss: 0.0011 - 785ms/epoch - 2ms/step
# Epoch 97/100
# 494/494 - 1s - loss: 0.0011 - 895ms/epoch - 2ms/step
# Epoch 98/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 99/100
# 494/494 - 1s - loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 100/100
# 494/494 - 1s - loss: 0.0011 - 808ms/epoch - 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# DOW Train Score: 0.36 RMSE
# Finished training model for DOW
